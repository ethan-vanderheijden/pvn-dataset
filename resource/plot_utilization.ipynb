# %%
import pandas as pd
import seaborn as sns

DATA_FILE = "utilization_data/rdr_5.csv"
FIELD = "cpu"

# %%
# Timeseries
data = pd.read_csv(DATA_FILE)
sns.lineplot(data=data, x="time", y=FIELD, hue="system")
# Out:
# <Axes: xlabel='time', ylabel='cpu'>

# %%
# Histogram
sns.histplot(data=data, x=FIELD, hue="system", element="step", stat="density", common_norm=False)
# Out:
# <Axes: xlabel='cpu', ylabel='Density'>
